# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [raw]
# Legend:
#     R – Runs scored: number of times a player crosses home plate
#     AB – At bat: Plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
#     H – Hits: times reached base because of a batted, fair ball without error by the defense
#     2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
#     3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
#     HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
#     BB – Base on balls (aka "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base
#     SO – Strike out(K): number of times that a third strike is taken or swung at and missed, or bunted foul. Catcher must catch the third strike or batter may attempt to run to first base
#     SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
#     RA - Runs allowed
#     ER – Earned run: number of runs that did not occur as a result of errors or passed balls
#     ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
#     CG – Complete game: number of games where player was the only pitcher for his team
#     SHO – Shutout: number of complete games pitched with no runs allowed
#     SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
#     E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %% [markdown]
# Based of Baseball statistics, we can add lot of new features based on the base information we have. To know more about baseball statistics, refer to https://en.wikipedia.org/wiki/Baseball_statistics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr())

# %% [markdown]
# As we can see, data is highly correlated to many features within the data. Let's check for any outliers

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#Graphical representation to look for outliers
df.plot(kind='box',subplots=True,layout=(3,6))
# Out:
# W         AxesSubplot(0.125,0.657941;0.110714x0.222059)
# R      AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# AB     AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# H      AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# 2B     AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# 3B     AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# HR        AxesSubplot(0.125,0.391471;0.110714x0.222059)
# BB     AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# SO     AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# SB     AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# RA     AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# ER     AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# ERA          AxesSubplot(0.125,0.125;0.110714x0.222059)
# CG        AxesSubplot(0.257857,0.125;0.110714x0.222059)
# SHO       AxesSubplot(0.390714,0.125;0.110714x0.222059)
# SV        AxesSubplot(0.523571,0.125;0.110714x0.222059)
# E         AxesSubplot(0.656429,0.125;0.110714x0.222059)
# ...

# %% [markdown]
# Seems like there are outliers, especially for 'E

# %%
print(df['E'].describe())
sns.countplot(df['E'])
# Out:
# count     30.000000
# mean      94.333333
# std       13.958889
# min       75.000000
# 25%       86.000000
# 50%       91.000000
# 75%       96.750000
# max      126.000000
# Name: E, dtype: float64

# %%
#Let's plot boxplot separately for 'E'
sns.boxplot(df['E'])

# %%
#Mathematical representation to look for outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
#Using threshold value as 3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#Only one point seems to be an outlier
z[5][1]
# Out:
# 3.5096470447193067

# %%
df.shape
# Out:
# (30, 17)

# %%
df_new=df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (29, 17)

# %%
sns.pairplot(df_new)

# %%
#Checking for any null data
df_new.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 29
# Data columns (total 17 columns):
# W      29 non-null int64
# R      29 non-null int64
# AB     29 non-null int64
# H      29 non-null int64
# 2B     29 non-null int64
# 3B     29 non-null int64
# HR     29 non-null int64
# BB     29 non-null int64
# SO     29 non-null int64
# SB     29 non-null int64
# RA     29 non-null int64
# ER     29 non-null int64
# ERA    29 non-null float64
# CG     29 non-null int64
# SHO    29 non-null int64
# SV     29 non-null int64
# E      29 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 5.3 KB

# %%
x=df_new.iloc[:,1:]
x.head(5)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
y=df_new.iloc[:,0]
y.head(5)
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)
pd.DataFrame(x)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# # Machine Learning Algorithms

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print('x_train.shape: ',x_train.shape,'x_test.shape: ',x_test.shape,'\ny_train.shape',y_train.shape,'y_test.shape',y_test.shape)
# Out:
# x_train.shape:  (23, 16) x_test.shape:  (6, 16)
# y_train.shape (23,) y_test.shape (6,)

# %%
#Creating function for Model Training
from sklearn.metrics import mean_squared_error, r2_score
def models(model, x_train, x_test, y_train, y_test,score,rmse):
    #Fit the algorithm on the data
    model.fit(x_train, y_train)
    
    #Predict training set:
    y_pred = model.predict(x_test)
    
    score.append(model.score(x_train,y_train))
    rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    
    print('\nModel Report')
    print('Score:',model.score(x_train,y_train))
    print('RMSE:',np.sqrt(mean_squared_error(y_test, y_pred)))
    print('R2 Score:',r2_score(y_test, y_pred))

# %%
model_name,score,rmse=[],[],[]

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
models(lreg,x_train,x_test,y_train,y_test,score,rmse)
model_name.append('Linear Regression')
# Out:
# Model Report
# Score: 0.9669863192160294
# RMSE: 8.447227107765814
# R2 Score: 0.2592839535276099

# %%
from sklearn.model_selection import GridSearchCV

# %%
#Ridge Regression
from sklearn.linear_model import Ridge
parameters={'alpha':[0.01,1,100]}
best=GridSearchCV(Ridge(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 1}

# %%
rr=Ridge(alpha=1)
models(rr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Ridge Regression')
# Out:
# Model Report
# Score: 0.9345847084585568
# RMSE: 5.397307588229699
# R2 Score: 0.6976028110522987

# %%
#Lasso Regression
from sklearn.linear_model import Lasso
parameters={'alpha':[0.001,0.01,1]}
best=GridSearchCV(Lasso(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'alpha': 1}

# %%
lr=Lasso(alpha=1)
models(lr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Lasso Regression')
# Out:
# Model Report
# Score: 0.884270581871989
# RMSE: 4.62141380862577
# R2 Score: 0.7782962049423154

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.01)
models(enr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Elastic Net')
# Out:
# Model Report
# Score: 0.9461396060830952
# RMSE: 4.451736532405481
# R2 Score: 0.7942772509970217

# %%
#Support Vector Regression
from sklearn.svm import SVR
parameters={'kernel':['linear','poly','rbf']}
best=GridSearchCV(SVR(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'kernel': 'linear'}

# %%
svr=SVR(kernel='linear')
models(svr,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Support Vector Regression')
# Out:
# Model Report
# Score: 0.9161411626297151
# RMSE: 5.33807090942375
# R2 Score: 0.7042041415151963

# %%
#Decision Tree Regressor Model
from sklearn.tree import DecisionTreeRegressor
parameters={'max_depth':[8,10,12,15],'min_samples_leaf':[100,150]}
best=GridSearchCV(DecisionTreeRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 8, 'min_samples_leaf': 100}

# %%
dct=DecisionTreeRegressor(max_depth=8,min_samples_leaf=100)
models(dct,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Decision Tree Regression')
# Out:
# Model Report
# Score: 0.0
# RMSE: 9.839576478711026
# R2 Score: -0.005023515021487235

# %%
#Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
parameters={'n_estimators':[200,300,400],'max_depth':[5,6]}
best=GridSearchCV(RandomForestRegressor(),parameters)
best.fit(x_train,y_train)
best.best_params_
# Out:
# {'max_depth': 6, 'n_estimators': 300}

# %%
rf=RandomForestRegressor(n_estimators=300,max_depth=5)
models(rf,x_train, x_test, y_train, y_test,score,rmse)
model_name.append('Random Forest Regression')
# Out:
# Model Report
# Score: 0.9488117869337405
# RMSE: 6.723740834953084
# R2 Score: 0.5307056316718105

# %%
final=pd.DataFrame({'Model Name':model_name,'Score':score,'RMSE':rmse})
final
# Out:
#                   Model Name     Score      RMSE
# 0          Linear Regression  0.966986  8.447227
# 1           Ridge Regression  0.934585  5.397308
# 2           Lasso Regression  0.884271  4.621414
# 3                Elastic Net  0.946140  4.451737
# 4  Support Vector Regression  0.916141  5.338071
# 5   Decision Tree Regression  0.000000  9.839576
# 6   Random Forest Regression  0.948812  6.723741

# %% [markdown]
# The above data clearly shows that Linear Regression is th best model for this dataset

# %%
import joblib
from joblib import dump
joblib.dump(lreg,'Linear_Baseball_Dataset.pkl')
# Out:
# ['Linear_Baseball_Dataset.pkl']
